# %% [markdown]
# Configurar o ambiente

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

local = '/Users/fernandovieira/Library/CloudStorage/OneDrive-Pessoal/5. Trabalho/Expediente/Ativos/CGE/a. Hora-Atividade/III. Auditoria e Controle 2/SA/OS 240-2021/Piloto Setasc/Dados SER Familia/CADUNICO_SETASC/CadUnico_Julho2021_Anonimizada.csv'

# %% [markdown]
# Carregar e formatar o dataframe

# %%
df = pd.read_csv(local, low_memory=False)

# %%
glossario = pd.DataFrame({'original': df.columns})

# %%
## Renomear as colunas
abrevia_colunas = []
for i in range(0, df.columns.size):
    ac = 'Q'+str(i)
    abrevia_colunas.append(ac)

df.columns = abrevia_colunas

# %%
## Criar planilha glossário
glossario['abreviado'] = pd.DataFrame(df.columns)
glossario.to_csv('glossario.csv') 
# coluna explicacao editada manualmente, com base no 'Dicionario_de_Variaveis_CECAD.pdf'

# %%
pd.read_csv('glossario.csv')
# Out:
#      Unnamed: 0                  original abreviado                                         explicacao
# 0             0                 d_cd_ibge        Q0                            CódigodoIBGEdomunicípio
# 1             1        d_cod_familiar_fam        Q1                                     CódigoFamiliar
# 2             2   d_dat_cadastramento_fam        Q2  Data do cadastramento da Família - formato DD/...
# 3             3           d_dat_atual_fam        Q3  Data da última atualização da família no forma...
# 4             4   d_cod_est_cadastral_fam        Q4  Estado cadastral da família (1 - Em cadastrame...
# ..          ...                       ...       ...                                                ...
# 159         160     p_ind_dinh_outro_memb      Q160                                                NaN
# 160         161  p_ind_dinh_nao_resp_memb      Q161                                                NaN
# 161         162   p_ind_atend_nenhum_memb      Q162                                                NaN
# 162         163                 p_ref_cad      Q163                                                NaN
# 163         164                 p_ref_pbf      Q164                                                NaN
#
# [164 rows x 4 columns]
