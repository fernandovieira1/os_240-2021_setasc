# %%
import pandas as pd

# %%
pd.read_csv('glossario_os.csv')
# Out:
#      Unnamed: 0                  original abreviado  \
# 0             0                 d_cd_ibge        Q0
# 1             1        d_cod_familiar_fam        Q1
# 2             2   d_dat_cadastramento_fam        Q2
# 3             3           d_dat_atual_fam        Q3
# 4             4   d_cod_est_cadastral_fam        Q4
# ..          ...                       ...       ...
# 159         160     p_ind_dinh_outro_memb      Q160
# 160         161  p_ind_dinh_nao_resp_memb      Q161
# 161         162   p_ind_atend_nenhum_memb      Q162
# 162         163                 p_ref_cad      Q163
# 163         164                 p_ref_pbf      Q164
#
#                                             explicacao formato  socioeconomico
# 0                          Código do IBGE do município  object             NaN
# 1                                      Código Familiar  object             NaN
# 2    Data do cadastramento da Família - formato DD/...     NaN             NaN
# ...
